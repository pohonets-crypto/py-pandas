# %% [markdown]
# # Pandas

# %% [markdown]
# ## Task 1
#
# You should import the necessary libraries. You will use `numpy` and `pandas` libraries.
#
#
# > Don't forget to import `numpy`, and `pandas` in short form.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Task 2
#
# Create a `DataFrame` from the given dictionary `data`.

# %%
data = {
    "Name": ["John", "Emily", "Ryan"],
    "Age": [16, 28, 22],
    "City": ["New York", "Los Angeles", "Chicago"],
}

data_table = pd.DataFrame(data)

# %% [markdown]
# ## Task 3
#
# In this task you should complete the following steps:

# %% [markdown]
# ### Task 3.1
# Display all data for `Age` column for the DataFrame you created in the previous task.

# %%
data_table.Age
# Out:
# 0    16
# 1    28
# 2    22
# Name: Age, dtype: int64

# %% [markdown]
# ### Task 3.2
#
# Add `Salary` column to the `DataFrame` with the values `[50000, 60000, 45000]`.

# %%
salary = pd.Series([50000, 60000, 45000], name="Salary")
data_table["Salary"] = salary
print(data_table)
# Out:
#     Name  Age         City  Salary
# 0   John   16     New York   50000
# 1  Emily   28  Los Angeles   60000
# 2   Ryan   22      Chicago   45000

# %% [markdown]
# ### Task 3.3
#
# Filter the `DataFrame` to show only the rows with the `Age` greater than 18.

# %%
data_table[(data_table["Age"] > 18)]
# Out:
#     Name  Age         City  Salary
# 1  Emily   28  Los Angeles   60000
# 2   Ryan   22      Chicago   45000

# %% [markdown]
# ## Task 4
#
# In this task you should complete the following steps:

# %% [markdown]
# ### Task 4.1
#
# Add new calculated field `Birth year`;

# %%
data_table["Birth_year"] = 2026 - data_table["Age"]
print(data_table)
# Out:
#     Name  Age         City  Salary  Birth_year
# 0   John   16     New York   50000        2010
# 1  Emily   28  Los Angeles   60000        1998
# 2   Ryan   22      Chicago   45000        2004

# %% [markdown]
# ### Task 4.2
#
# Add new calculated field `Average age`.

# %%
data_table["Average age"] = data_table["Age"].mean()
print(data_table)
# Out:
#     Name  Age         City  Salary  Birth_year  Average age
# 0   John   16     New York   50000        2010         22.0
# 1  Emily   28  Los Angeles   60000        1998         22.0
# 2   Ryan   22      Chicago   45000        2004         22.0

# %% [markdown]
# ### Task 4.3
#
# Calculate absolute difference between `Age` and `Average age`.

# %%
data_table["Different age"] = (data_table["Age"] - data_table["Average age"]).abs()
print(data_table)
# Out:
#     Name  Age         City  Salary  Birth_year  Average age  Different age
# 0   John   16     New York   50000        2010         22.0            6.0
# 1  Emily   28  Los Angeles   60000        1998         22.0            6.0
# 2   Ryan   22      Chicago   45000        2004         22.0            0.0

# %% [markdown]
# ## Task 5
#
# Complete the following tasks described below.

# %% [markdown]
# ### Task 5.1
#
# You have two dictionaries `data1` and `data2`. Create two `DataFrame` objects from these dictionaries. Then, `concatenate`, and `merge` these two `DataFrame` objects into one `DataFrame` object, and see the difference.

# %%
# Data
data1 = {'Name': ['John', 'Emily', 'Ryan'],
         'Age': [25, 28, 22]}
data2 = {'Name': ['Emily', 'Ryan', 'Mike'],
         'City': ['Los Angeles', 'Chicago', 'Houston']}

df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

# %%
pd.merge(df1, df2, on='Name')
# Out:
#     Name  Age         City
# 0  Emily   28  Los Angeles
# 1   Ryan   22      Chicago

# %%
pd.concat([df1, df2])
# Out:
#     Name   Age         City
# 0   John  25.0          NaN
# 1  Emily  28.0          NaN
# 2   Ryan  22.0          NaN
# 0  Emily   NaN  Los Angeles
# 1   Ryan   NaN      Chicago
# 2   Mike   NaN      Houston

# %% [markdown]
# ### Task 5.2
#
# You have two `Series` objects `s1` and `s2`. Make default mathematical operations on these two `Series` objects. Such as `+`, `-`, `*`, `/`, `**`, `//`, `%`. Also, filter `s1` and print only even numbers, and `s2` only with odd numbers.

# %%
s1 = pd.Series([1, 2, 3, 4, 5])
s2 = pd.Series([6, 7, 8, 9, 10])

# %%
# use + operator here
s1 + s2
# Out:
# 0     7
# 1     9
# 2    11
# 3    13
# 4    15
# dtype: int64

# %%
# use - operator here
s1 - s2
# Out:
# 0   -5
# 1   -5
# 2   -5
# 3   -5
# 4   -5
# dtype: int64

# %%
# use * operator here
s1 * s2
# Out:
# 0     6
# 1    14
# 2    24
# 3    36
# 4    50
# dtype: int64

# %%
# use / operator here
s1 / s2
# Out:
# 0    0.166667
# 1    0.285714
# 2    0.375000
# 3    0.444444
# 4    0.500000
# dtype: float64

# %%
# use ** operator here
s1 ** s2
# Out:
# 0          1
# 1        128
# 2       6561
# 3     262144
# 4    9765625
# dtype: int64

# %%
# use // operator here
s1 // s2
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# dtype: int64

# %%
# use % operator here
s1 % s2
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
# filter s1 here
s1[s1 % 2 == 0]
# Out:
# 1    2
# 3    4
# dtype: int64

# %%
# filter s2 here
s2[s2 % 2 == 1]
# Out:
# 1    7
# 3    9
# dtype: int64

# %% [markdown]
# ### Task 5.3
#
# You have a `Serias` object `s`. Make the following operations on this `Series` object:
#
# * make all words in uppercase without loops;
# * get length of each word without loops.

# %%
s = pd.Series(["numpy", "pandas", "matplotlib"])

# %%
# make all words in uppercase
s.str.upper()
# Out:
# 0         NUMPY
# 1        PANDAS
# 2    MATPLOTLIB
# dtype: str

# %%
# get length of each wor
s.str.len()
# Out:
# 0     5
# 1     6
# 2    10
# dtype: int64

# %% [markdown]
# ## Task 6 Optional
#
# You have a large dataset consisting of a series of numbers. Your task is to calculate the moving average of the series using a window of `5` elements. The moving average is the average of a set of consecutive values in the series, where the window `slides` through the series to compute the average at each position. The goal is to calculate the moving average efficiently and accurately. Also, compare time performance of Python and Pandas solutions.
#
# > Please, note: If you get `nan` while calculating the moving average, you should remove it from the result. Pandas solution should take 1-2 lines of code.

# %% [markdown]
# ### Python Solution
#
# In the Python solution, a large dataset is generated using random numbers. The moving average is computed by iterating over the dataset using a loop. At each position, a window of 5 elements is created, and the average is calculated by summing the values in the window and dividing by 5.

# %%
import random

def unknown_signature():
    # Generate a large dataset
    data = [random.randint(1, 100) for _ in range(10000000)]

    # Calculate the moving average with a window of 5
    moving_averages = []
    for i in range(4, len(data)):
        window = data[i - 4 : i + 1]
        average = sum(window) / 5
        moving_averages.append(average)
    return moving_averages[:10]

# %time unknown_signature()
# Out:
# CPU times: total: 3.39 s
# Wall time: 3.53 s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[59], line 15
#      12         moving_averages.append(average)
#      13     return moving_averages[:10]
# ---> 15 get_ipython().run_line_magic('time', 'unknown_signature()')
#
# File D:\Python Advanced\py-pandas\.venv\Lib\site-packages\IPython\core\interactiveshell.py:2511, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2509     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2510 with self.builtin_trap:
# -> 2511     result = fn(*args, **kwargs)
#    2513 # The code below prevents the output from being displayed
#    2514 # when using magics with decorator @output_can_be_silenced
#    2515 # when the last Python token in the expression is a ';'.
#    2516 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File D:\Python Advanced\py-pandas\.venv\Lib\site-packages\IPython\core\magics\execution.py:1447, in ExecutionMagics.time(self, line, cell, local_ns)
#    1445 if interrupt_occured:
#    1446     if exit_on_interrupt and captured_exception:
# -> 1447         raise captured_exception
#    1448     return
#    1449 return out
#
# File D:\Python Advanced\py-pandas\.venv\Lib\site-packages\IPython\core\magics\execution.py:1397, in ExecutionMagics.time(self, line, cell, local_ns)
#    1395 st = clock2()
#    1396 try:
# -> 1397     out = eval(code, glob, local_ns)
#    1398 except KeyboardInterrupt as e:
#    1399     captured_exception = e
#
# File <timed eval>:1
#
# Cell In[59], line 5, in unknown_signature()
#       3 def unknown_signature():
#       4     # Generate a large dataset
# ----> 5     data = [random.randint(1, 100) for _ in range(10000000)]
#       7     # Calculate the moving average with a window of 5
#       8     moving_averages = []
#
# Cell In[59], line 5, in <listcomp>(.0)
#       3 def unknown_signature():
#       4     # Generate a large dataset
# ----> 5     data = [random.randint(1, 100) for _ in range(10000000)]
#       7     # Calculate the moving average with a window of 5
#       8     moving_averages = []
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\random.py:362, in Random.randint(self, a, b)
#     358 def randint(self, a, b):
#     359     """Return random integer in range [a, b], including both end points.
#     360     """
# --> 362     return self.randrange(a, b+1)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\random.py:284, in Random.randrange(self, start, stop, step)
#     279     return self.getrandbits(n * 8).to_bytes(n, 'little')
#     282 ## -------------------- integer methods  -------------------
# --> 284 def randrange(self, start, stop=None, step=_ONE):
#     285     """Choose a random item from range(start, stop[, step]).
#     286
#     287     This fixes the problem with randint() which includes the
#     288     endpoint; in Python this is usually not what you want.
#     289
#     290     """
#     292     # This code is a bit messy to make it fast for the
#     293     # common case while still doing adequate error checking.
#
# KeyboardInterrupt:

# %% [markdown]
# ### Solution using Pandas and Numpy

# %%
# write your code here
moving_avg_pd = data.rolling(window=5).mean().dropna()
# %time
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
